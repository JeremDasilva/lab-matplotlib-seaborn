# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
c1 = plt.plot(x, y)
plt.show()

# %%
c2 = plt.plot(x, z)
plt.show()

# %%
plt.plot(x, z, 'bo')
plt.ylabel("y**2")
plt.xlabel("x")
plt.title('square')
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
plt.subplot(1, 2, 1)
plt.plot(x,y)

plt.subplot(1, 2, 2)
plt.plot(x,z)

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
make_subplots(rows=1, cols=2)
plt.figure(figsize = (12,6))
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title('x*2')

plt.subplot(1, 2, 2)
plt.plot(x,z)
plt.title('x**2')

plt.show()

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
make_subplots(rows=2, cols=2)

plt.figure(figsize = (12,6))
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.yscale('log')
plt.title('x*2')

plt.subplot(1, 2, 2)
plt.plot(x,z)
plt.yscale('log')
plt.title('x**2')

plt.show()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('Fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED

#We first look at our data to decide which plot will be the best
for i in range(1,13):
    condition = fitbit['Months_encoded'] == i
    print(f'average steps for month {i} is {fitbit[condition].Steps.mean()}')
average_per_month = [round(fitbit[fitbit['Months_encoded'] == i].Steps.mean(),2) for i in range (1,13)]
print(average_per_month)

#I estimate that bar plot is the best:
plt.bar(range(5,17), average_per_month)
plt.xticks(range(5,17), ['May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'January', 'February', 'March', 'April'], rotation = 45)
plt.show()

# MEDIAN STEPS BY WORK_OR_WEEKEND
#We do the same as above
#1 is week, 0 is week end
for i in range(2):
    condition = fitbit['Work_or_Weekend'] == i
    print(f'average steps for {i} is {fitbit[condition].Steps.mean()}')
avg_week_or_weekend = [round(fitbit[fitbit['Work_or_Weekend'] == i].Steps.mean(),2) for i in range (2)]
plt.bar(range(2), avg_week_or_weekend)
plt.xticks(range(2), ['Week-end', 'Week'])
plt.show()
# Out:
# average steps for month 1 is 9892.064516129032
# average steps for month 2 is 8922.866666666667
# average steps for month 3 is 10312.935483870968
# average steps for month 4 is 13079.033333333333
# average steps for month 5 is 10620.09677419355
# average steps for month 6 is 12536.166666666666
# average steps for month 7 is 9193.322580645161
# average steps for month 8 is 11584.774193548386
# average steps for month 9 is 9191.333333333334
# average steps for month 10 is 8272.451612903225
# average steps for month 11 is 9467.466666666667
# average steps for month 12 is 8470.064516129032
# [9892.06, 8922.87, 10312.94, 13079.03, 10620.1, 12536.17, 9193.32, 11584.77, 9191.33, 8272.45, 9467.47, 8470.06]
# average steps for 0 is 10064.238095238095
# average steps for 1 is 10144.57251908397

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
print(fitbit.columns)
# Out:
# Index(['Date', 'Calorie burned', 'Steps', 'Distance', 'Floors',
#        'Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active',
#        'Minutes Very Active', 'Activity Calories', 'MinutesOfSleep',
#        'MinutesOfBeingAwake', 'NumberOfAwakings', 'LengthOfRestInMinutes',
#        'Distance_miles', 'Days', 'Days_encoded', 'Work_or_Weekend',
#        'Hours Sleep', 'Sleep efficiency', 'Yesterday_sleep',
#        'Yesterday_sleep_efficiency', 'Months', 'Months_encoded'],
#       dtype='object')

# %%
df_activness = fitbit[['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']]
df_activness
# Out:
#      Minutes Lightly Active  Minutes Very Active  Minutes Sedentary
# 0                        46                    0              1.355
# 1                       316                   60            611.000
# 2                       226                   77            602.000
# 3                       190                    4            749.000
# 4                       171                    0            876.000
# ..                      ...                  ...                ...
# 362                     275                   79            599.000
# 363                     333                   55            684.000
# 364                     287                   90            701.000
# 365                     298                   85            575.000
# 366                     370                   10            564.000
#
# [367 rows x 3 columns]

# %%
# your code here
plt.subplots(3,1)
for i, col in enumerate(df_activness.columns):
    plt.subplot(i+1,1,1)
    plt.scatter(x=df_activness[col], y=fitbit['Steps'])
    plt.xlabel(col)
    plt.ylabel('Steps')
    plt.show()
# Out:
# C:\Users\misol\AppData\Local\Temp\ipykernel_5220\1577606348.py:4: MatplotlibDeprecationWarning:
#
# Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
df_titanic = pd.read_csv('titanic.csv')
df_titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name  Gender        Age  \
# 0                            Braund, Mr. Owen Harris    male  22.000000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                             Heikkinen, Miss. Laina  female  26.000000
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                           Allen, Mr. William Henry    male  35.000000
# 5                                   Moran, Mr. James    male  23.926502
# 6                            McCarthy, Mr. Timothy J    male  54.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
df_titanic_numerical = df_titanic.select_dtypes(include='number')
df_titanic_numerical
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
df_titanic_categorical = df_titanic.select_dtypes(include='object')
df_titanic_categorical
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.hist(df_titanic_numerical['Age'], bins = 50)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
plt.subplot(1, 3, 1)
plt.hist(df_titanic_numerical['Age'], bins = 10)
plt.xlabel('Age')
plt.ylabel('Count')

plt.subplot(1, 3, 2)
plt.hist(df_titanic_numerical['Age'], bins = 20)
plt.xlabel('Age')

plt.subplot(1, 3, 3)
plt.hist(df_titanic_numerical['Age'], bins = 50)
plt.xlabel('Age')

plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The bins size affects how we see the distribution. If we use a small bin size, we can visualize the distribution per bigger range, and if the closer the bin size is to the number of value, the more we will look at it per values
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.histplot(df_titanic_numerical['Age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.bar(df_titanic_categorical.Gender.unique(), height=df_titanic_categorical.Gender.value_counts())
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.catplot(df_titanic_categorical, x='Gender', kind='count')
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.catplot(df_titanic_numerical, x='Pclass', kind='count')
plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
df_titanic_numerical['Age'].describe()
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
plt.boxplot(df_titanic_numerical.Age, vert=False)
plt.show()

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
We have some outliers, people aged 60+. Most of people onboard were people aged 22-37 and majority of people 22-28.5
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
#In a subplot, we will diplay a histogram above a box plot
# your code here
plt.subplot(2, 1, 1)
plt.hist(df_titanic_numerical['Age'], bins = 50)
plt.ylabel('Count')

plt.subplot(2, 1, 2)
plt.boxplot(df_titanic_numerical.Age, vert=False)
plt.xlabel('Age')

plt.show()

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
Now we can say that they were a few young/children people. That the 25% younger people where a majority of adolescent of teenager. 
In opposite, looking at people 37+, the oldest people is, the fewer they were
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(y=df_titanic.Fare, x=df_titanic.Age)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(y=df_titanic.Fare, x=df_titanic.Age)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
titanic_correl = df_titanic_numerical.corr()

mask = np.zeros_like(titanic_correl)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(titanic_correl, mask=mask, annot=True, cmap='RdYlGn')
# Out:
# <Axes: >

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
The most correlated feature, althought it is not strongly correlated, is Pclass/Fare
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
fig = make_subplots(rows=3, cols=1)

fig.add_trace(go.Box(x = df_titanic_numerical[df_titanic_numerical['Pclass'] == 1]['Age'], name='Age', marker=dict(color='blue')), row=1, col=1)
fig.add_trace(go.Box(x = df_titanic_numerical[df_titanic_numerical['Pclass'] == 2]['Age'], name='Age', marker=dict(color='green')), row=2, col=1)
fig.add_trace(go.Box(x = df_titanic_numerical[df_titanic_numerical['Pclass'] == 3]['Age'], name='Age', marker=dict(color='red')), row=3, col=1)

# Adjust the height, width, and title of the layout
fig.update_layout(height=800, width=1000, title_text="Target & Feature")
fig.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
fig = make_subplots(rows=2, cols=1)

fig.add_trace(go.Histogram(x = df_titanic[df_titanic['Gender'] == 'male']['Age'], name='Male', marker=dict(color='blue'), nbinsx = 50), row=1, col=1)
fig.add_trace(go.Histogram(x = df_titanic[df_titanic['Gender'] == 'female']['Age'], name='Female', marker=dict(color='green'), nbinsx = 50), row=2, col=1)

# Adjust the height, width, and title of the layout
fig.update_layout(height=800, width=1000, title_text="Target & Feature")
fig.show()
